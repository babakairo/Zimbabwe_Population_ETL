# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
url = "https://www.worldometers.info/world-population/zimbabwe-population/"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# %%
table = soup.find('table',class_='table table-striped table-bordered table-hover table-condensed table-list')

# %%
table_rows = table.find_all('tr')

# %%
hearder_row = table.find('thead')
if hearder_row:
    header_names = [header.text.strip() for header in hearder_row.find_all('th')]
    print(header_names)
else:
    print("Table header not found.")
# Out:
# ['Year', 'Population', 'Yearly %  Change', 'Yearly Change', 'Migrants (net)', 'Median Age', 'Fertility Rate', 'Density (P/Km²)', 'Urban Pop %', 'Urban Population', "Country's Share of World Pop", 'World Population', 'ZimbabweGlobal Rank']

# %%
hh = []
for header in hearder_row:
    he = header.text.strip()
    hh.append(he)

hh
# Out:
# ['',
#  "YearPopulationYearly %  ChangeYearly ChangeMigrants (net)Median AgeFertility RateDensity (P/Km²)Urban Pop %Urban PopulationCountry's Share of World PopWorld PopulationZimbabweGlobal Rank"]

# %%
#storing each row in a list
data = []
for row in table.find_all('tr')[1:]:
    row_data = [cell.text.strip() for cell in row.find_all('td')]
    data.append(row_data)
    
data
# Out:
# [['2024',
#   '17,020,321',
#   '2.13 %',
#   '354,912',
#   '-9,999',
#   '18.6',
#   '3.34',
#   '44',
#   '36.8 %',
#   '6,269,464',
#   '0.21 %',
#   '8,118,835,999',
#   '74'],
#  ['2023',
#   '16,665,409',
#   '2.11 %',
#   '344,872',
#   '-9,999',
#   '18.4',
#   '3.39',
#   '43',
#   '36.7 %',
#   '6,117,511',
#   '0.21 %',
#   '8,045,311,447',
#   '74'],
#  ['2022',
#   '16,320,537',
#   '2.04 %',
#   '327,013',
#   '-9,999',
#   '18.2',
#   '3.44',
#   '42',
#   '36.6 %',
#   '5,972,826',
#   '0.20 %',
#   '7,975,105,156',
#   '74'],
#  ['2020',
#   '15,669,666',
#   '2.05 %',
#   '315,058',
#   '-29,955',
#   '17.9',
#   '3.55',
#   '41',
#   '36.4 %',
#   '5,700,460',
#   '0.20 %',
#   '7,840,952,880',
#   '74'],
#  ['2015',
#   '14,154,937',
#   '1.97 %',
#   '263,033',
#   '-59,918',
#   '17.0',
#   '3.85',
#   '37',
#   '36.1 %',
#   '5,109,485',
#   '0.19 %',
#   '7,426,597,537',
#   '72'],
#  ['2010',
#   '12,839,771',
#   '0.99 %',
#   '123,004',
#   '-133,402',
#   '17.1',
#   '4.03',
#   '33',
#   '36.4 %',
#   '4,676,106',
#   '0.18 %',
#   '6,985,603,105',
#   '71'],
#  ['2005',
#   '12,224,753',
#   '0.65 %',
#   '78,015',
#   '-164,732',
#   '17.3',
#   '3.67',
#   '32',
#   '36.1 %',
#   '4,413,866',
#   '0.19 %',
#   '6,558,176,119',
#   '70'],
#  ['2000',
#   '11,834,676',
#   '1.48 %',
#   '168,127',
#   '-137,321',
#   '16.8',
#   '3.97',
#   '31',
#   '34.9 %',
#   '4,125,989',
#   '0.19 %',
#   '6,148,898,975',
#   '66'],
#  ['1995',
#   '10,994,041',
#   '1.68 %',
#   '176,030',
#   '-32,961',
#   '15.6',
#   '4.15',
#   '28',
#   '32.7 %',
#   '3,592,151',
#   '0.19 %',
#   '5,743,219,454',
#   '64'],
#  ['1990',
#   '10,113,893',
#   '3.08 %',
#   '284,676',
#   '2,355',
#   '14.8',
#   '4.87',
#   '26',
#   '29.2 %',
#   '2,951,918',
#   '0.19 %',
#   '5,316,175,862',
#   '69'],
#  ['1985',
#   '8,690,515',
#   '4.27 %',
#   '328,118',
#   '1,785',
#   '14.5',
#   '5.90',
#   '22',
#   '25.3 %',
#   '2,200,595',
#   '0.18 %',
#   '4,861,730,613',
#   '72'],
#  ['1980',
#   '7,049,926',
#   '2.95 %',
#   '190,569',
#   '389,244',
#   '14.1',
#   '6.61',
#   '18',
#   '22.7 %',
#   '1,602,677',
#   '0.16 %',
#   '4,444,007,706',
#   '76'],
#  ['1975',
#   '6,097,083',
#   '3.22 %',
#   '178,833',
#   '-29,003',
#   '14.5',
#   '6.98',
#   '16',
#   '19.9 %',
#   '1,215,331',
#   '0.15 %',
#   '4,069,437,231',
#   '80'],
#  ['1970',
#   '5,202,918',
#   '3.19 %',
#   '151,154',
#   '-24,103',
#   '14.6',
#   '7.09',
#   '13',
#   '17.3 %',
#   '898,584',
#   '0.14 %',
#   '3,695,390,336',
#   '81'],
#  ['1965',
#   '4,447,149',
#   '3.16 %',
#   '128,168',
#   '-10,889',
#   '14.5',
#   '7.26',
#   '11',
#   '14.5 %',
#   '644,767',
#   '0.13 %',
#   '3,337,111,983',
#   '89'],
#  ['1960',
#   '3,806,310',
#   '3.12 %',
#   '108,537',
#   '-8,256',
#   '15.3',
#   '7.22',
#   '10',
#   '12.4 %',
#   '472,478',
#   '0.13 %',
#   '3,019,233,434',
#   '87'],
#  ['1955',
#   '3,263,625',
#   '3.18 %',
#   '94,460',
#   '-6,491',
#   '16.2',
#   '7.14',
#   '8',
#   '11.4 %',
#   '371,106',
#   '0.12 %',
#   '2,746,072,141',
#   '89']]

# %%
df = pd.DataFrame(data, columns=header_names)

# %%
df
# Out:
#     Year  Population Yearly %  Change Yearly Change Migrants (net) Median Age  \
# 0   2024  17,020,321           2.13 %       354,912         -9,999       18.6
# 1   2023  16,665,409           2.11 %       344,872         -9,999       18.4
# 2   2022  16,320,537           2.04 %       327,013         -9,999       18.2
# 3   2020  15,669,666           2.05 %       315,058        -29,955       17.9
# 4   2015  14,154,937           1.97 %       263,033        -59,918       17.0
# 5   2010  12,839,771           0.99 %       123,004       -133,402       17.1
# 6   2005  12,224,753           0.65 %        78,015       -164,732       17.3
# 7   2000  11,834,676           1.48 %       168,127       -137,321       16.8
# 8   1995  10,994,041           1.68 %       176,030        -32,961       15.6
# 9   1990  10,113,893           3.08 %       284,676          2,355       14.8
# 10  1985   8,690,515           4.27 %       328,118          1,785       14.5
# 11  1980   7,049,926           2.95 %       190,569        389,244       14.1
# 12  1975   6,097,083           3.22 %       178,833        -29,003       14.5
# 13  1970   5,202,918           3.19 %       151,154        -24,103       14.6
# 14  1965   4,447,149           3.16 %       128,168        -10,889       14.5
# 15  1960   3,806,310           3.12 %       108,537         -8,256       15.3
# 16  1955   3,263,625           3.18 %        94,460         -6,491       16.2
#
#    Fertility Rate Density (P/Km²) Urban Pop % Urban Population  \
# 0            3.34              44      36.8 %        6,269,464
# 1            3.39              43      36.7 %        6,117,511
# 2            3.44              42      36.6 %        5,972,826
# 3            3.55              41      36.4 %        5,700,460
# 4            3.85              37      36.1 %        5,109,485
# 5            4.03              33      36.4 %        4,676,106
# 6            3.67              32      36.1 %        4,413,866
# 7            3.97              31      34.9 %        4,125,989
# 8            4.15              28      32.7 %        3,592,151
# 9            4.87              26      29.2 %        2,951,918
# 10           5.90              22      25.3 %        2,200,595
# 11           6.61              18      22.7 %        1,602,677
# 12           6.98              16      19.9 %        1,215,331
# 13           7.09              13      17.3 %          898,584
# 14           7.26              11      14.5 %          644,767
# 15           7.22              10      12.4 %          472,478
# 16           7.14               8      11.4 %          371,106
#
#    Country's Share of World Pop World Population ZimbabweGlobal Rank
# 0                        0.21 %    8,118,835,999                  74
# 1                        0.21 %    8,045,311,447                  74
# 2                        0.20 %    7,975,105,156                  74
# 3                        0.20 %    7,840,952,880                  74
# 4                        0.19 %    7,426,597,537                  72
# 5                        0.18 %    6,985,603,105                  71
# 6                        0.19 %    6,558,176,119                  70
# 7                        0.19 %    6,148,898,975                  66
# 8                        0.19 %    5,743,219,454                  64
# 9                        0.19 %    5,316,175,862                  69
# 10                       0.18 %    4,861,730,613                  72
# 11                       0.16 %    4,444,007,706                  76
# 12                       0.15 %    4,069,437,231                  80
# 13                       0.14 %    3,695,390,336                  81
# 14                       0.13 %    3,337,111,983                  89
# 15                       0.13 %    3,019,233,434                  87
# 16                       0.12 %    2,746,072,141                  89
